# %% [markdown]
# # Ilist : aggregation
#
# ## Goals
#
# - understand the Ilist aggregation process
#
# <img src="https://loco-philippe.github.io/ES/ilist_aggregation.png" width="800">
#
#
# -----

# %%
import os
os.chdir('../../ES')
from ilist import Ilist
from pprint import pprint

# %% [markdown]
# ## example
# In this example, the documentation process has two step :
# - a simple documentation for each people
# - an aggregation of all results
#
# The merge method provides a complete Ilist image of all the results (aggregation is the reference, merge is the image)
#
# <img src="https://loco-philippe.github.io/ES/ilist_merge.png" width="700">

# %%
aw = Ilist.Idic({'score'     : [11, 13, 15, 10, 12], 
                 'course'    : ['math', 'math', 'math', 'english', 'english'],
                 'year'      : [2021, 2021, 2021, 2021, 2021],
                 'examen'    : ['t1', 't2', 't3', 't2', 't3']}, var=0)              
pw = Ilist.Idic({'score'     : [15, 8], 
                 'year'      : [2021, 2021],
                 'course'    : ['math', 'english'],
                 'examen'    : ['t1', 't2']}, var=0)  
cr = Ilist.Idic({'score'     : [17, 18, 2, 4], 
                 'course'    : ['software', 'software', 'english', 'english'],
                 'year'      : [2021, 2021, 2021, 2021],
                 'examen'    : ['t3', 't2', 't1', 't2']}, var=0)               
pb = Ilist.Idic({'score'     : [18, 6], 
                 'course'    : ['software', 'english'],
                 'year'      : [2021, 2021],
                 'examen'    : ['t3', 't1']}, var=0)        

total = Ilist.Idic({'score'     : [aw, pw, cr, pb],
                    'full name' : ['anne white', 'philippe white', 'camille red', 'philippe black'],
                    'last name' : ['white', 'white', 'red', 'black'],
                    'first name': ['anne', 'philippe', 'camille', 'philippe'],
                    'surname'   : ['skyler', 'heisenberg', 'saul', 'gus'],
                    'group'     : ['gr1', 'gr2', 'gr3','gr3']}, var=0)

print('the aggregate Ilist has the same property as non aggregate Ilist :\n')
print('record number : ', len(total), 'Iindex number : ', total.lenindex)
print('\nbinary representation : \n', total.to_obj(encoded=True, encode_format='cbor'))
print('\njson representation : \n', total.to_obj())
# Out:
# the aggregate Ilist has the same property as non aggregate Ilist :
#
# record number :  4 Iindex number :  6
#
# binary representation :
#  b'\x86\x83escore\x84\xa1eilist\x84\x83escore\x85\x0b\r\x0f\n\x0c \x83fcourse\x82genglishdmath\x85\x01\x01\x01\x00\x00\x82dyear\x81\x19\x07\xe5\x83fexamen\x83bt3bt1bt2\x85\x01\x02\x00\x02\x00\xa1eilist\x84\x83escore\x82\x0f\x08 \x82dyear\x81\x19\x07\xe5\x83fcourse\x82genglishdmath\x82\x01\x00\x83fexamen\x82bt2bt1\x02\xa1eilist\x84\x83escore\x84\x11\x12\x02\x04 \x83fcourse\x82hsoftwaregenglish\x84\x00\x00\x01\x01\x82dyear\x81\x19\x07\xe5\x83fexamen\x83bt3bt1bt2\x84\x00\x02\x01\x02\xa1eilist\x84\x83escore\x82\x12\x06 \x82fcourse\x82hsoftwaregenglish\x82dyear\x81\x19\x07\xe5\x83fexamen\x82bt3bt1\x01 \x83ifull name\x84kcamille rednphilippe whitenphilippe blackjanne white\x84\x03\x01\x00\x02\x83ilast name\x83credewhiteeblack\x82\x01\x84\x00\x01\x02\x01\x83jfirst name\x83dannehphilippegcamille\x82\x01\x84\x02\x01\x01\x00\x83gsurname\x84dsauljheisenbergcgusfskyler\x01\x83egroup\x83cgr1cgr2cgr3\x82\x01\x84\x02\x01\x02\x00'
#
# json representation :
#  [['score', [{'ilist': [['score', [11, 13, 15, 10, 12], -1], ['course', ['english', 'math'], [1, 1, 1, 0, 0]], ['year', [2021]], ['examen', ['t3', 't1', 't2'], [1, 2, 0, 2, 0]]]}, {'ilist': [['score', [15, 8], -1], ['year', [2021]], ['course', ['english', 'math'], [1, 0]], ['examen', ['t2', 't1'], 2]]}, {'ilist': [['score', [17, 18, 2, 4], -1], ['course', ['software', 'english'], [0, 0, 1, 1]], ['year', [2021]], ['examen', ['t3', 't1', 't2'], [0, 2, 1, 2]]]}, {'ilist': [['score', [18, 6], -1], ['course', ['software', 'english']], ['year', [2021]], ['examen', ['t3', 't1'], 1]]}], -1], ['full name', ['camille red', 'philippe white', 'philippe black', 'anne white'], [3, 1, 0, 2]], ['last name', ['red', 'white', 'black'], [1, [0, 1, 2, 1]]], ['first name', ['anne', 'philippe', 'camille'], [1, [2, 1, 1, 0]]], ['surname', ['saul', 'heisenberg', 'gus', 'skyler'], 1], ['group', ['gr1', 'gr2', 'gr3'], [1, [2, 1, 2, 0]]]]

# %%
img = total.merge(mergeidx=True) #.full().setcanonorder()

print('complete image : \n', img)
print('\ncomplete image optimize format: \n', img.to_obj())

img.to_file('score.il', encode_format='cbor')                # reuse in other Notebook

img2 = total.merge(mergeidx=True).full().setcanonorder()
print('\ncomplete image optimize canonical format: \n', img2.to_obj())
# Out:
# complete image :
#      ["score", [11, 13, 15, 10, 12, 15, 8, 17, 18, 2, 4, 18, 6]]
#
#     ["full name", ["anne white", "anne white", "anne white", "anne white", "anne white", "philippe white", "philippe white", "camille red", "camille red", "camille red", "camille red", "philippe black", "philippe black"]]
#     ["last name", ["white", "white", "white", "white", "white", "white", "white", "red", "red", "red", "red", "black", "black"]]
#     ["first name", ["anne", "anne", "anne", "anne", "anne", "philippe", "philippe", "camille", "camille", "camille", "camille", "philippe", "philippe"]]
#     ["surname", ["skyler", "skyler", "skyler", "skyler", "skyler", "heisenberg", "heisenberg", "saul", "saul", "saul", "saul", "gus", "gus"]]
#     ["group", ["gr1", "gr1", "gr1", "gr1", "gr1", "gr2", "gr2", "gr3", "gr3", "gr3", "gr3", "gr3", "gr3"]]
#     ["course", ["math", "math", "math", "english", "english", "math", "english", "software", "software", "english", "english", "software", "english"]]
#     ["year", [2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021]]
#     ["examen", ["t1", "t2", "t3", "t2", "t3", "t1", "t2", "t3", "t2", "t1", "t2", "t3", "t1"]]
#
#
# complete image optimize format:
#  [['score', [11, 13, 15, 10, 12, 15, 8, 17, 18, 2, 4, 18, 6], -1], ['full name', ['camille red', 'philippe white', 'philippe black', 'anne white'], [3, 3, 3, 3, 3, 1, 1, 0, 0, 0, 0, 2, 2]], ['last name', ['red', 'white', 'black'], [1, [0, 1, 2, 1]]], ['first name', ['anne', 'philippe', 'camille'], [1, [2, 1, 1, 0]]], ['surname', ['saul', 'heisenberg', 'gus', 'skyler'], 1], ['group', ['gr1', 'gr2', 'gr3'], [1, [2, 1, 2, 0]]], ['course', ['software', 'english', 'math'], [2, 2, 2, 1, 1, 2, 1, 0, 0, 1, 1, 0, 1]], ['year', [2021]], ['examen', ['t3', 't1', 't2'], [1, 2, 0, 2, 0, 1, 2, 0, 2, 1, 2, 0, 1]]]
#
# complete image optimize canonical format:
#  [['full name', ['camille red', 'philippe white', 'philippe black', 'anne white']], ['course', ['software', 'english', 'math']], ['examen', ['t3', 't1', 't2']], ['last name', ['red', 'white', 'black'], [0, [0, 1, 2, 1]]], ['first name', ['anne', 'philippe', 'camille'], [0, [2, 1, 1, 0]]], ['surname', ['saul', 'heisenberg', 'gus', 'skyler'], 0], ['group', ['gr1', 'gr2', 'gr3'], [0, [2, 1, 2, 0]]], ['year', [2021]], ['score', [17, '-', 18, '-', 2, 4, '-', '-', '-', '-', '-', '-', '-', '-', 8, '-', 15, '-', 18, '-', '-', '-', 6, '-', '-', '-', '-', '-', '-', '-', 12, '-', 10, 15, 11, 13], -1]]
