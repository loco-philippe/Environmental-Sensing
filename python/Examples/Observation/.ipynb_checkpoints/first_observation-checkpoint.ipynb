# %% [markdown]
# # Object: First Observation
# ## Goal
# Show on a simple example the capacities of Obs tools
#
# ------

# %%
# This cell is only to prepare data for the example
import os, json, folium
with open('departements-version-simplifiee.geojson') as f: dp = f.read()
os.chdir('../../ES')
from ESObs import Obs
#from ESValue import NamedValue, ESValue, LocationValue, DatationValue
from pprint import pprint

paris       = [2.35, 48.87]
lyon        = [4.83, 45.76]
marseille   = [5.38, 43.3]
dpt = json.loads(dp)['features']
pol13 = {dpt[12]['properties']['code'] + ' ' + dpt[12]['properties']['nom'] : dpt[12]['geometry']['coordinates']}
pol69 = {dpt[69]['properties']['code'] + ' ' + dpt[69]['properties']['nom'] : dpt[69]['geometry']['coordinates']}
pol75 = {dpt[75]['properties']['code'] + ' ' + dpt[75]['properties']['nom'] : dpt[75]['geometry']['coordinates']}

# %% [markdown]
# ## Observation
# An observation is a set of results in response to the questions: when, where, what, how much.
# The most simple and complete Observation you can create is for example :

# %%
ob = Obs.Std('high', 'morning', 'paris', ' Temp')

# This Observation can be supplemented by other results :

ob.append(['low', 'morning', 'lyon', ' Temp'])
ob.append(['very high', 'morning', 'marseille', ' Temp'])
# Out:
# [2, 0, 2, 0]

# %% [markdown]
# We can see this Observation in different ways :
#  - The "view" shows you a list with all the informations (eg CSV file).
#  - The "voxel" represent the quantity of data for each axe ( 1 for Datation, 3 for Location, 1 for Property).
#  - The "json" is a the representation of the data in the JSON format.

# %%
ob.view()
ob.voxel()
pprint(ob.json())
# Out:
# result       datation    location     property
# -----------  ----------  -----------  ----------
# "high"       "morning"   "paris"      " Temp"
# "low"        "morning"   "lyon"       " Temp"
# "very high"  "morning"   "marseille"  " Temp"
# {'data': [['result', ['high', 'low', 'very high'], -1],
#           ['datation', ['morning']],
#           ['location', ['paris', 'lyon', 'marseille']],
#           ['property', [' Temp']]],
#  'type': 'obs'}

# %% [markdown]
# The String values can be changed to numerical values. It allows to use plotting functions

# %%
ob.nindex('result').setlistvalue([25, 10, 35])
ob.plot()
# Out:
# {'location': ['"paris"', '"lyon"', '"marseille"']}

# %% [markdown]
# Similarly if we complete the alphanumeric Location values with geographic coordinates, we can visualize the data
# on a map with point or polygon if the area is large :

# %%
print(ob.nindex('location'))
ob.nindex('location').setlistvalue([paris, lyon, marseille], valueonly=True) # ie paris = [2.35, 48.87]
ob.view()
display(ob.choropleth())
print('\n', ob.nindex('location'))
ob.nindex('location').setlistvalue([pol75, pol69, pol13],  valueonly=True) # ie pol75 = {'75 Paris': [[[2.416, 48.849]....      
display(ob.choropleth())
# Out:
#     ["location", ["paris", "lyon", "marseille"]]
#
#   result  datation    location                     property
# --------  ----------  ---------------------------  ----------
#       25  "morning"   {"paris": [2.35, 48.87]}     " Temp"
#       10  "morning"   {"lyon": [4.83, 45.76]}      " Temp"
#       35  "morning"   {"marseille": [5.38, 43.3]}  " Temp"
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f1af096935f158572657131232d115d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f1af096935f158572657131232d115d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9f1af096935f158572657131232d115d = L.map(
#                 &quot;map_9f1af096935f158572657131232d115d&quot;,
#                 {
#                     center: [45.76, 4.83],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4704990b0c479a93d6b97f0950e775b9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f1af096935f158572657131232d115d);
#
#
#             var choropleth_f3afb900bcc44342aae87401719a6e90 = L.featureGroup(
#                 {}
#             ).addTo(map_9f1af096935f158572657131232d115d);
#
#
#         function geo_json_75b8649398f81cc4468651de797a8bf2_styler(feature) {
#             switch(feature.id) {
#                 case 1:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.4, &quot;weight&quot;: 2};
#                 case 2:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.4, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.4, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_75b8649398f81cc4468651de797a8bf2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_75b8649398f81cc4468651de797a8bf2 = L.geoJson(null, {
#                 onEachFeature: geo_json_75b8649398f81cc4468651de797a8bf2_onEachFeature,
#
#                 style: geo_json_75b8649398f81cc4468651de797a8bf2_styler,
#         });
#
#         function geo_json_75b8649398f81cc4468651de797a8bf2_add (data) {
#             geo_json_75b8649398f81cc4468651de797a8bf2
#                 .addData(data)
#                 .addTo(choropleth_f3afb900bcc44342aae87401719a6e90);
#         }
#             geo_json_75b8649398f81cc4468651de797a8bf2_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [4.83, 45.76], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 0, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [2.35, 48.87], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 1, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [5.38, 43.3], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 2, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     var color_map_19952547d150b030c7064c59e48ebcbc = {};
#
#
#     color_map_19952547d150b030c7064c59e48ebcbc.color = d3.scale.threshold()
#               .domain([10.0, 10.050100200400802, 10.100200400801603, 10.150300601202405, 10.200400801603207, 10.250501002004007, 10.30060120240481, 10.350701402805612, 10.400801603206412, 10.450901803607215, 10.501002004008017, 10.551102204408817, 10.60120240480962, 10.651302605210422, 10.701402805611222, 10.751503006012024, 10.801603206412826, 10.851703406813627, 10.901803607214429, 10.951903807615231, 11.002004008016032, 11.052104208416834, 11.102204408817634, 11.152304609218437, 11.202404809619239, 11.252505010020041, 11.302605210420841, 11.352705410821644, 11.402805611222444, 11.452905811623246, 11.503006012024048, 11.55310621242485, 11.603206412825651, 11.653306613226453, 11.703406813627254, 11.753507014028056, 11.803607214428858, 11.853707414829659, 11.90380761523046, 11.953907815631263, 12.004008016032063, 12.054108216432866, 12.104208416833668, 12.154308617234468, 12.20440881763527, 12.254509018036073, 12.304609218436873, 12.354709418837675, 12.404809619238478, 12.454909819639278, 12.50501002004008, 12.555110220440882, 12.605210420841683, 12.655310621242485, 12.705410821643287, 12.755511022044088, 12.80561122244489, 12.85571142284569, 12.905811623246493, 12.955911823647295, 13.006012024048097, 13.056112224448897, 13.1062124248497, 13.1563126252505, 13.206412825651302, 13.256513026052104, 13.306613226452907, 13.356713426853707, 13.40681362725451, 13.45691382765531, 13.507014028056112, 13.557114228456914, 13.607214428857716, 13.657314629258517, 13.707414829659319, 13.75751503006012, 13.807615230460922, 13.857715430861724, 13.907815631262526, 13.957915831663327, 14.008016032064127, 14.05811623246493, 14.108216432865731, 14.158316633266534, 14.208416833667336, 14.258517034068136, 14.308617234468937, 14.358717434869739, 14.4088176352
#      ["location", [{"paris": [2.35, 48.87]}, {"lyon": [4.83, 45.76]}, {"marseille": [5.38, 43.3]}]]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b997c0a25abb64f73490c2b61da5607 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b997c0a25abb64f73490c2b61da5607&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1b997c0a25abb64f73490c2b61da5607 = L.map(
#                 &quot;map_1b997c0a25abb64f73490c2b61da5607&quot;,
#                 {
#                     center: [43.54523, 5.08489],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1525b0e57d0b4926b18d8a4c1d94400e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b997c0a25abb64f73490c2b61da5607);
#
#
#             var choropleth_6228d6b89a94a15236027387867b2e39 = L.featureGroup(
#                 {}
#             ).addTo(map_1b997c0a25abb64f73490c2b61da5607);
#
#
#         function geo_json_ccd4a74b032f87179496dee262b62b48_styler(feature) {
#             switch(feature.id) {
#                 case 0:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#b30000&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.4, &quot;weight&quot;: 2};
#                 case 1:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.4, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fef0d9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.4, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_ccd4a74b032f87179496dee262b62b48_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ccd4a74b032f87179496dee262b62b48 = L.geoJson(null, {
#                 onEachFeature: geo_json_ccd4a74b032f87179496dee262b62b48_onEachFeature,
#
#                 style: geo_json_ccd4a74b032f87179496dee262b62b48_styler,
#         });
#
#         function geo_json_ccd4a74b032f87179496dee262b62b48_add (data) {
#             geo_json_ccd4a74b032f87179496dee262b62b48
#                 .addData(data)
#                 .addTo(choropleth_6228d6b89a94a15236027387867b2e39);
#         }
#             geo_json_ccd4a74b032f87179496dee262b62b48_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[4.821736, 43.912828], [4.853094, 43.911382], [4.885235, 43.900147], [4.902319, 43.887932], [4.925858, 43.886493], [4.966309, 43.871647], [4.996089, 43.846063], [5.029533, 43.827793], [5.049656, 43.788726], [5.173314, 43.738809], [5.187972, 43.735103], [5.22999, 43.747673], [5.255714, 43.746558], [5.318503, 43.735021], [5.341019, 43.719704], [5.439246, 43.681104], [5.532692, 43.658982], [5.571562, 43.661923], [5.606944, 43.658686], [5.64775, 43.675796], [5.674082, 43.693545], [5.71735, 43.693527], [5.73695, 43.716004], [5.753651, 43.724622], [5.782189, 43.706888], [5.803458, 43.679673], [5.799061, 43.660518], [5.744798, 43.656778], [5.700228, 43.641716], [5.681084, 43.612516], [5.691599, 43.584428], [5.655965, 43.577401], [5.669257, 43.564733], [5.695816, 43.562141], [5.722822, 43.548161], [5.716142, 43.504297], [5.698803, 43.48217], [5.729498, 43.464946], [5.750366, 43.434837], [5.786516, 43.41454], [5.749995, 43.401512], [5.72443, 43.408874], [5.682787, 43.399157], [5.694567, 43.364398], [5.705025, 43.355918], [5.686454, 43.340188], [5.680571, 43.320568], [5.69104, 43.312963], [5.726601, 43.317355], [5.749842, 43.289268], [5.760929, 43.267338], [5.738053, 43.262349], [5.683909, 43.236058], [5.671875, 43.179269], [5.652556, 43.187315], [5.624166, 43.186983], [5.600902, 43.162545], [5.569124, 43.175294], [5.531324, 43.212042], [5.510066, 43.19769], [5.454402, 43.210642], [5.391052, 43.212128], [5.363644, 43.207125], [5.34087, 43.214641], [5.348353, 43.229821], [5.372524, 43.245078], [5.366241, 43.269298], [5.345688, 43.282363], [5.364413, 43.31214], [5.32386, 43.356939], [5.296472, 43.359557], [5.256252, 43.337274], [5.221336, 43.328359], [5.177477, 43.333616], [5.168325, 43.327941], [5.037908, 43.329028], [5.019042, 43.342944], [5.024294, 43.355561], [4.975888, 43.402252], [4.967706, 43.426105], [4.931382, 43.433157], [4.906351, 43.419742], [4.864259, 43.40622], [4.848994, 43.374446], [4.874828, 43.360495], [4.855049, 43.332617], [4.833032, 43.32987], [4.783363, 43.347194], [4.717739, 43.350307], [4.661783, 43.346412], [4.585805, 43.360069], [4.5628, 43.372137], [4.557428, 43.38832], [4.587702, 43.400712], [4.582043, 43.430561], [4.562102, 43.44325], [4.516352, 43.454716], [4.465265, 43.457156], [4.402201, 43.447264], [4.382042, 43.452274], [4.230283, 43.460185], [4.239684, 43.499175], [4.295852, 43.514535], [4.35365, 43.547394], [4.40935, 43.561128], [4

# %% [markdown]
# We now add some more Results with a new Property (Humidity) :

# %%
morning = ob.setDatation[0]
locparis, loclyon, locmarseille = ob.setLocation
ob.append([30, morning, locparis, 'Humidity'])
ob.append(['60', morning, locmarseille, 'Humidity'])
# Out:
# [4, 0, 2, 1]

# %% [markdown]
# In the several views, we see that the values are now distributed along two dimensions (Location, Property).

# %%
ob.view(location='n', width=40)
ob.voxel()
ob.plot()
# Out:
# result    datation    name-location    property
# --------  ----------  ---------------  ----------
# 25        "morning"   paris            " Temp"
# 10        "morning"   lyon             " Temp"
# 35        "morning"   marseille        " Temp"
# 30        "morning"   marseille        "Humidity"
# "60"      "morning"   lyon             "Humidity"
# {'location': ['{"marseille": [[[4.7',
#   '{"paris": [[[2.41634',
#   '{"lyon": [[[4.38808,'],
#  'property': ['" Temp"', '"Humidity"']}

# %% [markdown]
# ## Keep adding data !!
#
# We add now Result with a new Datation and we put the old Location values back (to keep data simple).
# For the Datation value, we add a timestamp.

# %%
ob.append([28, 'afternoon', locparis, ' Temp'])
ob.append([15, 'afternoon', loclyon, ' Temp'])
ob.nindex('location').setcodeclist([paris, lyon, marseille], valueonly=True)

# %% [markdown]
# The values are distributed along the three Dimension and the representations evolve to take the dimension
# into account.

# %%
ob.nindex('datation').setcodeclist(["2021-05-05T10", "2021-05-05T16"], valueonly=True)
ob.view(width=15)
ob.voxel()
ob.plot(order=[0,2,1])
# Out:
# result    datation         location         property
# --------  ---------------  ---------------  ----------
# 25        {"morning": "20  {"paris": [4.83  " Temp"
# 10        {"morning": "20  {"lyon": [5.38,  " Temp"
# 35        {"morning": "20  {"marseille": [  " Temp"
# 30        {"morning": "20  {"marseille": [  "Humidity"
# "60"      {"morning": "20  {"lyon": [5.38,  "Humidity"
# 28        {"afternoon": "  {"marseille": [  " Temp"
# 15        {"afternoon": "  {"paris": [4.83  " Temp"
# {'datation': ['{"morning": "2021-05', '{"afternoon": "2021-'],
#  'location': ['{"marseille": [2.35,',
#   '{"paris": [4.83, 45.',
#   '{"lyon": [5.38, 43.3'],
#  'property': ['" Temp"', '"Humidity"']}

# %% [markdown]
# Finally, we show you a new representation of the data with a Xarray : a 3D Matrix for the Result and some index
# for Location, Datation and Property. Xarray is very powerful to analyze and process this kind of data.
#
# You will notice that the data has been completed with nan values to fill in the matrix.

# %%
ob.to_xarray(numeric=True)
# Out:
# <xarray.DataArray (datation: 2, location: 3, property: 2)>
# array([[[35., 30.],
#         [25., nan],
#         [10., 60.]],
#
#        [[28., nan],
#         [15., nan],
#         [nan, nan]]])
# Coordinates:
#   * datation      (datation) object {"morning": "2021-05-05T10:00:00+00:00"} ...
#     datation_row  (datation) int32 0 1
#     datation_str  (datation) object '{"morning": "2021-05' '{"afternoon": "20...
#   * location      (location) object {"marseille": [2.35, 48.87]} ... {"lyon":...
#     location_row  (location) int32 0 1 2
#     location_str  (location) object '{"marseille": [2.35,' ... '{"lyon": [5.3...
#   * property      (property) object " Temp" "Humidity"
#     property_row  (property) int32 0 1
#     property_str  (property) object '" Temp"' '"Humidity"'

# %% [markdown]
# ------
# # Conclusion
# Here is a summary in terms of data :
# - the JSON show you all the data we define (in a very compact structure).
# - the Dictionnary presents the main informations associated to the Observation with in particular :
#     * the boundingbox for the Location value
#     * the timebox for the Datation value (an equivalent of the boundingbox for the dates)
#     * a 'complet' boolean to indicate if the matrix is full or not
#     * the 'measureRate' (ratio between the measure number and the complete number : 7 / 12 in the example)
#     * the dimension of the Observation (1, 2 or 3)
#     * the axes that make up the dimension.
#
# *Note: If you are very careful, you will notice that there is a problem with the Result values in the JSON
# because we don't know how to match a Result value to a Datation value, a Property value and a Location value
# and you are right !!*
#
# *This point will be clarified later.*

# %%
pprint(ob.json(fullcodec=True, defaultcodec=True, json_info=True), indent=2)
# Out:
# { 'data': [ ['result', [25, 10, 35, 30, '60', 28, 15], -1],
#             [ 'datation',
#               [ { 'morning': datetime.datetime(2021, 5, 5, 10, 0, tzinfo=datetime.timezone.utc)},
#                 { 'afternoon': datetime.datetime(2021, 5, 5, 16, 0, tzinfo=datetime.timezone.utc)}]],
#             [ 'location',
#               [ {'paris': [4.83, 45.76]},
#                 {'marseille': [2.35, 48.87]},
#                 {'lyon': [5.38, 43.3]}]],
#             ['property', [' Temp', 'Humidity']]],
#   'information': { 'axes': ['datation', 'location', 'property'],
#                    'complet': False,
#                    'datationBox': [ '2021-05-05T10:00:00+00:00',
#                                     '2021-05-05T16:00:00+00:00'],
#                    'dim': 3,
#                    'geobox': { 'coordinates': [ [ [5.38, 43.3],
#                                                   [5.38, 48.87],
#                                                   [2.35, 48.87],
#                                                   [2.35, 43.3],
#                                                   [5.38, 43.3]]],
#                                'type': 'Polygon'},
#                    'len-datation': 2,
#                    'len-location': 3,
#                    'len-property': 2,
#                    'len-result': 7,
#                    'locationBox': [2.35, 43.3, 5.38, 48.87],
#                    'propertyBox': ['-']},
#   'type': 'obs'}
